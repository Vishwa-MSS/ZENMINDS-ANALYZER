# %%
import pandas as pd

# List your CSV files here
files = [
    "1-17.csv",
    "18-25.csv",
    "26-final.csv",
    "30.csv"
]

# Read and merge all CSV files
df = pd.concat([pd.read_csv(file) for file in files], ignore_index=True)

# Save merged file
df.to_csv("merged_output.csv", index=False)

print("All files merged successfully into merged_output.csv")

# %%
import pandas as pd

# Read Excel file
df = pd.read_excel("file.xlsx")

# Column name from which you want unique values
column_name = "ColumnName"

# Get unique values
unique_values = df[column_name].dropna().unique()

# Convert to DataFrame
unique_df = pd.DataFrame(unique_values, columns=[column_name])

# Save to separate CSV file
unique_df.to_csv("unique_values_output.csv", index=False)

print("Unique values extracted and saved to unique_values_output.csv")
